# %%
from sklearn.ensemble import RandomForestClassifier
# Out:
# /home/ravi/miniconda3/envs/fastpy3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score, make_scorer

# %%
import pandas as pd

# %%
# !ls
# Out:
# forrest_256.csv  Linear.ipynb		sl_learn_ml.ipynb  train.csv  try1.zip
# forrest_32.csv	 sample_submission.csv	test.csv	   try1.csv

# %%
trn = pd.read_csv('train.csv')

# %%
trn.head(2)
# Out:
#    ID_code  target    var_0   var_1  ...  var_196  var_197  var_198  var_199
# 0  train_0       0   8.9255 -6.7863  ...   7.8784   8.5635  12.7803  -1.0914
# 1  train_1       0  11.5006 -4.1473  ...   8.1267   8.7889  18.3560   1.9518
#
# [2 rows x 202 columns]

# %%
x = trn.drop(['ID_code','target'],axis=1)

# %%
x.head(2)
# Out:
#      var_0   var_1    var_2  var_3  ...  var_196  var_197  var_198  var_199
# 0   8.9255 -6.7863  11.9081  5.093  ...   7.8784   8.5635  12.7803  -1.0914
# 1  11.5006 -4.1473  13.8588  5.389  ...   8.1267   8.7889  18.3560   1.9518
#
# [2 rows x 200 columns]

# %%
y = trn.target

# %%
cfr = RandomForestClassifier(n_estimators=9000,n_jobs=-1,max_depth=2)

# %%
# %time cfr.fit(x[:40000],y[:40000])
# Out:
# CPU times: user 16min 15s, sys: 1.17 s, total: 16min 17s
# Wall time: 1min 4s
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=2, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=9000, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
s = make_scorer(roc_auc_score)

# %%
s(cfr,x[40000:],y[40000:])
# Out:
# 0.5

# %%
cross_val_score(cfr,x,y)
# Out:
# /home/ravi/miniconda3/envs/fastpy3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# array([0.89950201, 0.899514  , 0.899514  ])

# %%
tst = pd.read_csv('test.csv')

# %%
tst.head(2)
# Out:
#   ID_code    var_0   var_1    var_2  ...  var_196  var_197  var_198  var_199
# 0  test_0  11.0656  7.7798  12.9536  ...   4.3654  10.7200  15.4722  -8.7197
# 1  test_1   8.5304  1.2543  11.3047  ...  -1.4852   9.8714  19.1293 -20.9760
#
# [2 rows x 201 columns]

# %%
tst_x = tst.drop('ID_code',axis=1)

# %%
cfr.fit(x,y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, n_estimators=256, n_jobs=15,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
preds = cfr.predict(tst_x)

# %%
preds
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
ss = pd.read_csv('sample_submission.csv',index_col = 'ID_code')

# %%
ss.head(2)
# Out:
#          target
# ID_code
# test_0        0
# test_1        0

# %%
ss.target = preds

# %%
ss.to_csv('xgb_99999.csv')

# %%
sol = pd.read_csv('forrest_32.csv',index_col='ID_code')

# %%
sol.head(2)
# Out:
#          target
# ID_code
# test_0        0
# test_1        0

# %%
# !kaggle c submit santander-customer-transaction-prediction -f xgb_99999.csv -m "99999 xgb"
# Out:
# ...
# 100%|███████████████████████████████████████| 2.56M/2.56M [00:10<00:00, 245kB/s]
# Successfully submitted to Santander Customer Transaction Prediction

# %%
from xgboost.sklearn import XGBClassifier

# %%
gbcfr = XGBClassifier()

# %%
cross_val_score(gbcfr,x,y)
# Out:
# /home/ravi/miniconda3/envs/fastpy3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# array([0.90118198, 0.90096901, 0.90086401])

# %%
import xgboost as xgb

# %%
x_ = trn.drop('ID_code',axis=1);
x_.head(2)
# Out:
#    target    var_0   var_1    var_2  ...  var_196  var_197  var_198  var_199
# 0       0   8.9255 -6.7863  11.9081  ...   7.8784   8.5635  12.7803  -1.0914
# 1       0  11.5006 -4.1473  13.8588  ...   8.1267   8.7889  18.3560   1.9518
#
# [2 rows x 201 columns]

# %%
trn_ = xgb.DMatrix(x,y)

# %%
trn_.save_binary('train.buffer')

# %%
tst.head(2)
# Out:
#   ID_code    var_0   var_1    var_2  ...  var_196  var_197  var_198  var_199
# 0  test_0  11.0656  7.7798  12.9536  ...   4.3654  10.7200  15.4722  -8.7197
# 1  test_1   8.5304  1.2543  11.3047  ...  -1.4852   9.8714  19.1293 -20.9760
#
# [2 rows x 201 columns]

# %%
tst_ = xgb.DMatrix(tst_x)

# %%
tst_.save_binary('test.buffer')

# %%
param = {'max_depth': 2, 'eta': 1, 'silent': 1, 'objective': 'binary:logistic'}
param['nthread'] = 16
param['eval_metric'] = 'auc'

# %%
evallist = [ (trn_, 'train')]

# %%
num_round = 100

# %%
bst = xgb.train(param, trn_, num_round, evallist)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-071b2b213552> in <module>
# ----> 1 bst = xgb.train(param, trn_, num_round, evallist,n_estimators=1)
#
# TypeError: train() got an unexpected keyword argument 'n_estimators'

# %%
bst.predict(tst_)
# Out:
# array([0.01958389, 0.37266484, 0.0706975 , ..., 0.00259538, 0.0119236 ,
#        0.06743246], dtype=float32)

# %%
trn_.get_label()
# Out:
# array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)

# %%
    model = xgb.XGBClassifier(max_depth=2,
                              n_estimators=99999,
                              colsample_bytree=0.3,
                              learning_rate=0.02,
                              objective='binary:logistic', 
                              n_jobs=-1)

# %%
#cross_val_score(model,x,y)

# %%
x.shape[0]
# Out:
# 200000

# %%
# %time model.fit(x,y)
# Out:
# CPU times: user 20h 14min 3s, sys: 13.5 s, total: 20h 14min 16s
# Wall time: 1h 16min 12s
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.3, gamma=0, learning_rate=0.02, max_delta_step=0,
#        max_depth=2, min_child_weight=1, missing=None, n_estimators=99999,
#        n_jobs=-1, nthread=None, objective='binary:logistic',
#        random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)

# %%
#p = model.predict(x[80000:90000])

# %%
s = make_scorer(roc_auc_score)

# %%
#s(model,x[80000:],y[80000:])
# Out:
# 0.6365416219496781

# %%
preds = model.predict(tst_x)
